# %%
#type() : 인자로 전달된 객체의 타입을 리턴

## 문자열을 날짜로 바꾸기
# date = '2022-01-01'
# date=datetime.strptime(date,'%Y-%m-%d')
# print(date)
# print(type(date))


# replace() 함수는 새로운 문자열을 반환하고 발견되는 모든 문자열을 바꿉니다:
# line.replace('o', '--')

## 3달전인 날짜를 구하는 법
# from datetime import datetime, timedelta

# date_str = "2022-01-23"
# date_obj = datetime.strptime(date_str, "%Y-%m-%d")

# three_months_ago = date_obj - timedelta(days=3*30)

# formatted_date = three_months_ago.strftime("%Y-%m-%d")
# print(formatted_date)


# a='2023.03.22'
# a.replace('.','-')


# input_value = 's23'  # 입력값으로 주어진 's23' 변수에 할당
# var_name = 'name_' + input_value  # 입력값으로부터 변수 이름 생성
# globals()[var_name] = []  # 생성된 변수 이름에 빈 리스트 할당


# # matches가 빈 리스트인 경우
# if not matches:







# import pandas as pd

# # A 리스트 생성
# A = pd.DataFrame({'col1': [1, 2, 3, 4, 5, 6, 7], 'col2': ['a', 'b', 'c', 'd', 'e', 'f', 'g']})
# print("Original A:")
# print(A)

# # 삭제할 행 번호 리스트
# pattern = [1, 5, 7]

# # 패턴에 해당하는 행 삭제
# A = A[~A.index.isin(pattern)]
# print("A after removing rows with pattern:")
# print(A)



#링크
#s23 : https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.media=0%26search.searchdate={}{}%26userDisplay=50%26search.option=0%26search.sortBy=date%26search.searchBy=1%26search.searchBlockYn=0%26search.query=s23%26search.viewtype=title%26search.page={}
#s22 : https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=s22&search.viewtype=title&search.page=
#s21 : https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=s21&search.viewtype=title&search.page=
#s20 : https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=s20&search.viewtype=title&search.page=
#z플립4 : https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%C7%C3%B8%B34&search.viewtype=title&search.page=
#z플립3 : https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%C7%C3%B8%B33&search.viewtype=title&search.page=
#z폴드4 : https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%C6%FA%B5%E54&search.viewtype=title&search.page=
#z폴드3 : https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%C6%FA%B5%E53&search.viewtype=title&search.page=
#아이폰14 : https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%BE%C6%C0%CC%C6%F914&search.viewtype=title&search.page=
#아이폰13 : https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%BE%C6%C0%CC%C6%F913&search.viewtype=title&search.page=
#아이폰12 : https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%BE%C6%C0%CC%C6%F912&search.viewtype=title&search.page=

s23="https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.media=0%26search.searchdate={}{}%26userDisplay=50%26search.option=0%26search.sortBy=date%26search.searchBy=1%26search.searchBlockYn=0%26search.query=s23%26search.viewtype=title%26search.page={}"
s22="https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate={}{}&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=s22&search.viewtype=title&search.page={}"
s21="https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate={}{}&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=s21&search.viewtype=title&search.page={}"
s20="https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate={}{}&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=s20&search.viewtype=title&search.page={}"
flip4= "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate={}{}&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%C7%C3%B8%B34&search.viewtype=title&search.page={}"
flip3= "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate={}{}&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%C7%C3%B8%B33&search.viewtype=title&search.page={}"
fold4 = "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate={}{}&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%C6%FA%B5%E54&search.viewtype=title&search.page={}"
fold3 = "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate={}{}&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%C6%FA%B5%E53&search.viewtype=title&search.page={}"
iphone14 = "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate={}{}&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%BE%C6%C0%CC%C6%F914&search.viewtype=title&search.page={}"
iphone13 ="https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate={}{}&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%BE%C6%C0%CC%C6%F913&search.viewtype=title&search.page={}"
iphone12 = "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate={}{}&search.defaultValue=1&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=%BE%C6%C0%CC%C6%F912&search.viewtype=title&search.page={}"

# %%
# Out:
# ['https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=1&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980902138&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=2&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980890755&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=3&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980878152&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=4&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980853698&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=5&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980774807&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=6&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980692754&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=7&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980679937&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=8&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980654289&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=9&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980563718&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=10&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980486186&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=11&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980475470&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=12&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980460428&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=13&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980436466&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=14&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980355244&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=15&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980294095&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=16&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980283582&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=17&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980270517&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=18&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980243917&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=19&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980173198&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=20&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980101869&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=21&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980093191&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=22&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980075072&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=23&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980050650&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=24&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979921315&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=25&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979895251&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=26&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979874259&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=27&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979846302&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=28&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979752991&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=29&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979695493&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=30&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979681008&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=31&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979656182&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=32&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979588908&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=33&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979488775&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=34&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979471218&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=35&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979425848&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=36&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979275427&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=37&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979243354&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=38&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979071312&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=39&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=979040191&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=40&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978914023&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=41&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=42&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=43&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=44&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=45&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=46&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=47&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=48&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=49&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=50&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=51&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=52&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=53&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=54&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=55&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=56&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=57&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=58&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=59&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=60&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=61&userDisplay=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=978868433&referrerAllArticles=true']

# %% [markdown]
# # selenium으로

# %%
    # https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.media=0%26search.searchdate=all%26userDisplay=15%26search.option=0%26search.sortBy=date%26search.searchBy=0%26search.searchBlockYn=0%26search.query=%B1%D7%B7%A5%26search.viewtype=title%26search.page=2

import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from datetime import datetime, timedelta

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import chromedriver_autoinstaller
import time
import requests
import pandas as pd

# path = "C:\study\python\datadown\chromedriver.exe"
# driver = webdriver.Chrome(path)

# driver.get("https://cafe.naver.com/joonggonara")
# time.sleep(2)
# #위 페이지가 모두 열릴 때까지 2초 대기

# driver = webdriver.Chrome('C:/Users/82104/Downloads/chromedriver_win32 (4).zip/chromedriver.exe')

# html = requests.get(url= "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&userDisplay=15&search.option=0&search.sortBy=date&search.searchBy=0&search.searchBlockYn=0&search.query=%B1%D7%B7%A5&search.viewtype=title&search.page=1")
# # query=%B1%D7%B7%A5 그램으로 검색했는데 이 부분이 암호화처리되어있는 것을 확인할 수 있었음.

# soup = BeautifulSoup(html.text, "html.parser")
# print(soup)

# %% [markdown]
# # 수정이 끝난 것.

# %%
# s23,, 플러스


# 리스트 만들기
def digital_name(digital):
    title_name = 'title_' + digital
    url_name = 'url_' + digital
    number_name = 'number_'+digital
    name_name = 'name_' + digital
    dates_name = 'dates_' + digital
    
    
    globals()[title_name] = []
    globals()[url_name] = []
    globals()[number_name] = []
    globals()[name_name] = []
    globals()[dates_name] = []
    




def joongoNara(page,date,digital,d_url):



    
    #print(date)
    #print(date)
    
    
    # 날짜
    if date == 'all':
        html = requests.get(url= "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&userDisplay=15&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=s23&search.viewtype=title&search.page=" + str(page))
    else:
        print("else")
        date1 = datetime.strptime(date,"%Y%m%d")
        date2 = date1- timedelta(days = 12*30)
        date1 = date1.strftime("%Y%m%d")
        date2 = date2.strftime("%Y%m%d")
        print(date2,date1)
        #html = requests.get(url= "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.exact=&search.include=&userDisplay=50&search.exclude=&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.includeAll=&search.query=gram&search.viewtype=title&search.page=" + str(page))
        url= d_url.format(date2,date1,str(page))
        html = requests.get(url = url)


    
    
    
    soup = BeautifulSoup(html.text, "html.parser")
    
    ##만약 페이지안에 값이 없는 경우
    # 날짜 조정하기
    
    
    # 첫번쨰 컨텐츠로 가야함. 그리고 main-area는 복수개이기 떄문에 find_all과 몇번쨰 area인지 확인을 해줘야함.
    # 그래서 [0]을 써준 것임.
    junggo = soup.find("div", id = "content-area").find_all("div",id="main-area")[0].find_all("div", class_="article-board")[1]
    junggos = junggo.find("tbody").find_all("tr")
    
    #da = junggos[0].find("td", class_="td_date").text
    #print(da)
    print("page:{}".format(page))

    
    # 종료시점    
#     마지막 페이지인 경우.
#         전 페이지로 가서 날짜를 가져와
#     지금 날짜를 A로 놔.
#     A-3 달 부터 A달까지 중고나라 검색 다시해.
    
#     만약 현재 페이지가 1인 경우엔
#     함수 종료.


    # 만약 데이터가 없는 경우
    asd=junggo.find_all("div", class_="nodata")
    asd_text = str(asd)
    if "nodata" in asd_text:
        
        print("끝")
        
        # 지금 페이지가 1인데 아무것도 없는 경우 함수를 마친다.
        if page in (1,2,3):
            print("끝asd",page)
            return
        else:
            
            # 안에 데이터가 없는 경우.
            
            print("끝끝",page)
            
            #전페이지 접속
            
            html = requests.get(url = d_url.format(date2,date1,str(page-2)))
            
            soup = BeautifulSoup(html.text, "html.parser")
            junggo = soup.find("div", id = "content-area").find_all("div",id="main-area")[0].find_all("div", class_="article-board")[1]
            junggos = junggo.find("tbody").find_all("tr")
            
            da = junggos[0].find("td", class_="td_date").text
            #print(junggo)
            
            print("da:",da)
            
            # 전 페이지의 날짜 가져오기
            #print(junggo)

            date3= datetime.strptime(da, "%Y.%m.%d.")
            
            #date3= datetime.strftime(da,"%Y.%m.%d.")
            date3 = date3.strftime("%Y%m%d")
            
            return execution(101,date3,digital,d_url)

            # 전 페이지의 날짜를 가져와서 그 날짜로 중고나라 검색 다시하기
            
            
            
            #execution(i,date)
                #date로 url 고치기
                
            
            
    
    
    # 안에 있는 데이터 뽑기 반복
    
    for item in junggos:
        
        title = item.find("td", class_="td_article")
        name_box = item.find("td", class_="td_name")
        date_box = item.find("td", class_="td_date")
        
        if title == None:
            return

        elif title != None:
            source = title.find("div", class_="board-list").find("a", class_="article")
            inner_number = title.find("div", class_="board-number").find(class_="inner_number")
            name = name_box.find("div", class_="pers_nick_area").find("td", class_="p-nick").find("a", class_="m-tcol-c")
            dates = date_box.text
            
            if ':' in dates:
                dates = datetime.today().strftime("%Y.%m.%d")
            elif '.' in dates:
                dates = dates.strip('.')
                
            # 리스트에 넣기

                
            url = source['href']
            globals()['number_{}'.format(digital)].append(inner_number)
            globals()['title_{}'.format(digital)].append(" ".join(source.stripped_strings)) # 공백을 날리는 것이다.
            globals()['url_{}'.format(digital)].append("https://cafe.naver.com" + url)
            globals()['name_{}'.format(digital)].append(name.text)
            globals()['dates_{}'.format(digital)].append(dates)




##  execution: 중고나라 실행 함수 
def execution(i,date,digital,d_url):
    for i in range(1,i+1):
        print(i)
        joongoNara(i,date,digital,d_url)
        

digital_name('s23')
execution(101,'20230328','s23',s23)
# Out:
# 1
# else
# 20220402 20230328
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [106], in <cell line: 170>()
#     166         joongoNara(i,date,digital,d_url)
#     169 digital_name('s23')
# --> 170 execution(101,'20230328','s23',s23)
#
# Input In [106], in execution(i, date, digital, d_url)
#     164 for i in range(1,i+1):
#     165     print(i)
# --> 166     joongoNara(i,date,digital,d_url)
#
# Input In [106], in joongoNara(page, date, digital, d_url)
#      50 soup = BeautifulSoup(html.text, "html.parser")
#      52 ##만약 페이지안에 값이 없는 경우
#      53 # 날짜 조정하기
#      54
#      55
#      56 # 첫번쨰 컨텐츠로 가야함. 그리고 main-area는 복수개이기 떄문에 find_all과 몇번쨰 area인지 확인을 해줘야함.
#      57 # 그래서 [0]을 써준 것임.
# ---> 58 junggo = soup.find("div", id = "content-area").find_all("div",id="main-area")[0].find_all("div", class_="article-board")[1]
#      59 junggos = junggo.find("tbody").find_all("tr")
#      61 #da = junggos[0].find("td", class_="td_date").text
#      62 #print(da)
#
# IndexError: list index out of range

# %% [markdown]
# # 이전에 수정한 것

# %%
# s23,, 플러스


# 리스트 만들기
def digital_name(digital):
    title_name = 'title_' + digital
    url_name = 'url_' + digital
    number_name = 'number_'+digital
    name_name = 'name_' + digital
    dates_name = 'dates_' + digital
    
    
    globals()[title_name] = []
    globals()[url_name] = []
    globals()[number_name] = []
    globals()[name_name] = []
    globals()[dates_name] = []



def joongoNara(page,date,digital,d_url):


    
    #print(date)
    #print(date)
    
    
    # 날짜
    if date == 'all':
        html = requests.get(url= "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=s23&search.viewtype=title&search.page=" + str(page))
    else:
        print("else")
        date1 = datetime.strptime(date,"%Y%m%d")
        date2 = date1- timedelta(days = 12*30)
        date1 = date1.strftime("%Y%m%d")
        date2 = date2.strftime("%Y%m%d")
        print(date2,date1)
        #html = requests.get(url= "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.exact=&search.include=&userDisplay=50&search.exclude=&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.includeAll=&search.query=gram&search.viewtype=title&search.page=" + str(page))
        url="https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate={}{}&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=s23&search.viewtype=title&search.page={}".format(date2,date1,str(page))
        html = requests.get(url = url)

    
    

    
    
    soup = BeautifulSoup(html.text, "html.parser")
    
    ##만약 페이지안에 값이 없는 경우
    # 날짜 조정하기
    
    
    
    # 첫번쨰 컨텐츠로 가야함. 그리고 main-area는 복수개이기 떄문에 find_all과 몇번쨰 area인지 확인을 해줘야함.
    # 그래서 [0]을 써준 것임.
    junggo = soup.find("div", id = "content-area").find_all("div",id="main-area")[0].find_all("div", class_="article-board")[1]
    junggos = junggo.find("tbody").find_all("tr")
    
    #da = junggos[0].find("td", class_="td_date").text
    #print(da)
    print(page)

    
    # 종료시점    
#     마지막 페이지인 경우.
#         전 페이지로 가서 날짜를 가져와
#     지금 날짜를 A로 놔.
#     A-3 달 부터 A달까지 중고나라 검색 다시해.
    
#     만약 현재 페이지가 1인 경우엔
#     함수 종료.


    # 만약 데이터가 없는 경우
    asd=junggo.find_all("div", class_="nodata")
    asd_text = str(asd)
    if "nodata" in asd_text:
        
        print("끝")
        
        # 지금 페이지가 1인데 아무것도 없는 경우 함수를 마친다.
        if page in (1,2,3):
            print("끝asd",page)
            return
        else:
            
            # 안에 데이터가 없는 경우.
            
            print("끝끝",page)
            
            #전페이지 접속
            
            html = requests.get(url = "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate={}{}&userDisplay=50&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.query=s23&search.viewtype=title&search.page={}".format(date2,date1,str(page-2)))
            soup = BeautifulSoup(html.text, "html.parser")
            junggo = soup.find("div", id = "content-area").find_all("div",id="main-area")[0].find_all("div", class_="article-board")[1]
            junggos = junggo.find("tbody").find_all("tr")
            
            print(html)
            da = junggos[0].find("td", class_="td_date").text
            #print(junggo)
            
            print("da:",da)
            
            # 전 페이지의 날짜 가져오기
            #print(junggo)

            date3= datetime.strptime(da, "%Y.%m.%d.")
            
            #date3= datetime.strftime(da,"%Y.%m.%d.")
            date3 = date3.strftime("%Y%m%d")
            
            return execution(101,date3,digital,d_url)

            # 전 페이지의 날짜를 가져와서 그 날짜로 중고나라 검색 다시하기
            
            
            
            #execution(i,date)
                #date로 url 고치기
                
            
            
    
    
    # 안에 있는 데이터 뽑기 반복
    
    for item in junggos:
        
        
        title = item.find("td", class_="td_article")
        name_box = item.find("td", class_="td_name")
        date_box = item.find("td", class_="td_date")
        

        if title != None:
            source = title.find("div", class_="board-list").find("a", class_="article")
            inner_number = title.find("div", class_="board-number").find(class_="inner_number")
            name = name_box.find("div", class_="pers_nick_area").find("td", class_="p-nick").find("a", class_="m-tcol-c")
            dates = date_box.text
            
            if ':' in dates:
                dates = datetime.today().strftime("%Y.%m.%d")
            elif '.' in dates:
                dates = dates.strip('.')
                
            # 리스트에 넣기

                
            url = source['href']
            globals()['number_{}'.format(digital)].append(inner_number)
            globals()['title_{}'.format(digital)].append(" ".join(source.stripped_strings)) # 공백을 날리는 것이다.
            globals()['url_{}'.format(digital)].append("https://cafe.naver.com" + url)
            globals()['name_{}'.format(digital)].append(name.text)
            globals()['dates_{}'.format(digital)].append(dates)
            






##  execution: 중고나라 실행 함수 
def execution(i,date,digital,d_url):
    for i in range(1,i+1):
        print(i)
        joongoNara(i,date,digital,d_url)
        

digital_name('s23')
execution(101,'20230328','s23',s23)
# Out:
# 1
# else
# 20220402 20230328
# 1
# 2
# else
# 20220402 20230328
# 2
# 3
# else
# 20220402 20230328
# 3
# 4
# else
# 20220402 20230328
# 4
# 5
# else
# 20220402 20230328
# 5
# 6
# else
# 20220402 20230328
# 6
# 7
# else
# 20220402 20230328
# 7
# 8
# else
# 20220402 20230328
# 8
# 9
# else
# 20220402 20230328
# 9
# 10
# else
# 20220402 20230328
# 10
# 11
# else
# 20220402 20230328
# 11
# 12
# else
# 20220402 20230328
# 12
# 13
# else
# 20220402 20230328
# 13
# 14
# else
# 20220402 20230328
# 14
# 15
# else
# 20220402 20230328
# 15
# 16
# else
# 20220402 20230328
# 16
# 17
# else
# 20220402 20230328
# 17
# 18
# else
# 20220402 20230328
# 18
# 19
# else
# 20220402 20230328
# 19
# 20
# else
# 20220402 20230328
# 20
# 21
# else
# 20220402 20230328
# 21
# 22
# else
# 20220402 20230328
# 22
# 23
# else
# 20220402 20230328
# 23
# 24
# else
# 20220402 20230328
# 24
# 25
# else
# 20220402 20230328
# 25
# 26
# else
# 20220402 20230328
# 26
# 27
# else
# 20220402 20230328
# 27
# 28
# else
# 20220402 20230328
# 28
# 29
# else
# 20220402 20230328
# 29
# 30
# else
# 20220402 20230328
# 30
# 31
# else
# 20220402 20230328
# 31
# 32
# else
# 20220402 20230328
# 32
# 33
# else
# 20220402 20230328
# 33
# 34
# else
# 20220402 20230328
# 34
# 35
# else
# 20220402 20230328
# 35
# 36
# else
# 20220402 20230328
# 36
# 37
# else
# 20220402 20230328
# 37
# 38
# else
# 20220402 20230328
# 38
# 39
# else
# 20220402 20230328
# 39
# 40
# else
# 20220402 20230328
# 40
# 41
# else
# 20220402 20230328
# 41
# 42
# else
# 20220402 20230328
# 42
# 43
# else
# 20220402 20230328
# 43
# 44
# else
# 20220402 20230328
# 44
# 45
# else
# 20220402 20230328
# 45
# 46
# else
# 20220402 20230328
# 46
# 47
# else
# 20220402 20230328
# 47
# 48
# else
# 20220402 20230328
# 48
# 49
# else
# 20220402 20230328
# 49
# 50
# else
# 20220402 20230328
# 50
# 51
# else
# 20220402 20230328
# 51
# 52
# else
# 20220402 20230328
# 52
# 53
# else
# 20220402 20230328
# 53
# 54
# else
# 20220402 20230328
# 54
# 55
# else
# 20220402 20230328
# 55
# 56
# else
# 20220402 20230328
# 56
# 57
# else
# 20220402 20230328
# 57
# 58
# else
# 20220402 20230328
# 58
# 59
# else
# 20220402 20230328
# 59
# 60
# else
# 20220402 20230328
# 60
# 61
# else
# 20220402 20230328
# 61
# 62
# else
# 20220402 20230328
# 62
# 63
# else
# 20220402 20230328
# 63
# 64
# else
# 20220402 20230328
# 64
# 65
# else
# 20220402 20230328
# 65
# 66
# else
# 20220402 20230328
# 66
# 67
# else
# 20220402 20230328
# 67
# 68
# else
# 20220402 20230328
# 68
# 69
# else
# 20220402 20230328
# 69
# 70
# else
# 20220402 20230328
# 70
# 71
# else
# 20220402 20230328
# 71
# 72
# else
# 20220402 20230328
# 72
# 73
# else
# 20220402 20230328
# 73
# 74
# else
# 20220402 20230328
# 74
# 75
# else
# 20220402 20230328
# 75
# 76
# else
# 20220402 20230328
# 76
# 77
# else
# 20220402 20230328
# 77
# 78
# else
# 20220402 20230328
# 78
# 79
# else
# 20220402 20230328
# 79
# 80
# else
# 20220402 20230328
# 80
# 81
# else
# 20220402 20230328
# 81
# 82
# else
# 20220402 20230328
# 82
# 83
# else
# 20220402 20230328
# 83
# 84
# else
# 20220402 20230328
# 84
# 85
# else
# 20220402 20230328
# 85
# 86
# else
# 20220402 20230328
# 86
# 87
# else
# 20220402 20230328
# 87
# 88
# else
# 20220402 20230328
# 88
# 89
# else
# 20220402 20230328
# 89
# 90
# else
# 20220402 20230328
# 90
# 91
# else
# 20220402 20230328
# 91
# 92
# else
# 20220402 20230328
# 92
# 93
# else
# 20220402 20230328
# 93
# 94
# else
# 20220402 20230328
# 94
# 95
# else
# 20220402 20230328
# 95
# 96
# else
# 20220402 20230328
# 96
# 97
# else
# 20220402 20230328
# 97
# 98
# else
# 20220402 20230328
# 98
# 99
# else
# 20220402 20230328
# 99
# 100
# else
# 20220402 20230328
# 100
# 101
# else
# 20220402 20230328
# 101
# 끝
# 끝끝 101
# <Response [200]>
# da: 2023.03.18.
# 1
# else
# 20220323 20230318
# 1
# 2
# else
# 20220323 20230318
# 2
# 3
# else
# 20220323 20230318
# 3
# 4
# else
# 20220323 20230318
# 4
# 5
# else
# 20220323 20230318
# 5
# 6
# else
# 20220323 20230318
# 6
# 7
# else
# 20220323 20230318
# 7
# 8
# else
# 20220323 20230318
# 8
# 9
# else
# 20220323 20230318
# 9
# 10
# else
# 20220323 20230318
# 10
# 11
# else
# 20220323 20230318
# 11
# 12
# else
# 20220323 20230318
# 12
# 13
# else
# 20220323 20230318
# 13
# 14
# else
# 20220323 20230318
# 14
# 15
# else
# 20220323 20230318
# 15
# 16
# else
# 20220323 20230318
# 16
# 17
# else
# 20220323 20230318
# 17
# 18
# else
# 20220323 20230318
# 18
# 19
# else
# 20220323 20230318
# 19
# 20
# else
# 20220323 20230318
# 20
# 21
# else
# 20220323 20230318
# 21
# 22
# else
# 20220323 20230318
# 22
# 23
# else
# 20220323 20230318
# 23
# 24
# else
# 20220323 20230318
# 24
# 25
# else
# 20220323 20230318
# 25
# 26
# else
# 20220323 20230318
# 26
# 27
# else
# 20220323 20230318
# 27
# 28
# else
# 20220323 20230318
# 28
# 29
# else
# 20220323 20230318
# 29
# 30
# else
# 20220323 20230318
# 30
# 31
# else
# 20220323 20230318
# 31
# 32
# else
# 20220323 20230318
# 32
# 33
# else
# 20220323 20230318
# 33
# 34
# else
# 20220323 20230318
# 34
# 35
# else
# 20220323 20230318
# 35
# 36
# else
# 20220323 20230318
# 36
# 37
# else
# 20220323 20230318
# 37
# 38
# else
# 20220323 20230318
# 38
# 39
# else
# 20220323 20230318
# 39
# 40
# else
# 20220323 20230318
# 40
# 41
# else
# 20220323 20230318
# 41
# 42
# else
# 20220323 20230318
# 42
# 43
# else
# 20220323 20230318
# 43
# 44
# else
# 20220323 20230318
# 44
# 45
# else
# 20220323 20230318
# 45
# 46
# else
# 20220323 20230318
# 46
# 47
# else
# 20220323 20230318
# 47
# 48
# else
# 20220323 20230318
# 48
# 49
# else
# 20220323 20230318
# 49
# 50
# else
# 20220323 20230318
# 50
# 51
# else
# 20220323 20230318
# 51
# 52
# else
# 20220323 20230318
# 52
# 53
# else
# 20220323 20230318
# 53
# 54
# else
# 20220323 20230318
# 54
# 55
# else
# 20220323 20230318
# 55
# 56
# else
# 20220323 20230318
# 56
# 57
# else
# 20220323 20230318
# 57
# 58
# else
# 20220323 20230318
# 58
# 59
# else
# 20220323 20230318
# 59
# 60
# else
# 20220323 20230318
# 60
# 61
# else
# 20220323 20230318
# 61
# 62
# else
# 20220323 20230318
# 62
# 63
# else
# 20220323 20230318
# 63
# 64
# else
# 20220323 20230318
# 64
# 65
# else
# 20220323 20230318
# 65
# 66
# else
# 20220323 20230318
# 66
# 67
# else
# 20220323 20230318
# 67
# 68
# else
# 20220323 20230318
# 68
# 69
# else
# 20220323 20230318
# 69
# 70
# else
# 20220323 20230318
# 70
# 71
# else
# 20220323 20230318
# 71
# 72
# else
# 20220323 20230318
# 72
# 73
# else
# 20220323 20230318
# 73
# 74
# else
# 20220323 20230318
# 74
# 75
# else
# 20220323 20230318
# 75
# 76
# else
# 20220323 20230318
# 76
# 끝
# 끝끝 76
# <Response [200]>
# da: 2023.02.27.
# 1
# else
# 20220304 20230227
# 1
# 2
# else
# 20220304 20230227
# 2
# 3
# else
# 20220304 20230227
# 3
# 4
# else
# 20220304 20230227
# 4
# 5
# else
# 20220304 20230227
# 5
# 6
# else
# 20220304 20230227
# 6
# 7
# else
# 20220304 20230227
# 7
# 8
# else
# 20220304 20230227
# 8
# 9
# else
# 20220304 20230227
# 9
# 10
# else
# 20220304 20230227
# 10
# 11
# else
# 20220304 20230227
# 11
# 12
# else
# 20220304 20230227
# 12
# 13
# else
# 20220304 20230227
# 13
# 14
# else
# 20220304 20230227
# 14
# 15
# else
# 20220304 20230227
# 15
# 16
# else
# 20220304 20230227
# 16
# 17
# else
# 20220304 20230227
# 17
# 18
# else
# 20220304 20230227
# 18
# 19
# else
# 20220304 20230227
# 19
# 20
# else
# 20220304 20230227
# 20
# 21
# else
# 20220304 20230227
# 21
# 22
# else
# 20220304 20230227
# 22
# 23
# else
# 20220304 20230227
# 23
# 24
# else
# 20220304 20230227
# 24
# 25
# else
# 20220304 20230227
# 25
# 26
# else
# 20220304 20230227
# 26
# 27
# else
# 20220304 20230227
# 27
# 28
# else
# 20220304 20230227
# 28
# 29
# else
# 20220304 20230227
# 29
# 30
# else
# 20220304 20230227
# 30
# 31
# else
# 20220304 20230227
# 31
# 32
# else
# 20220304 20230227
# 32
# 33
# else
# 20220304 20230227
# 33
# 34
# else
# 20220304 20230227
# 34
# 35
# else
# 20220304 20230227
# 35
# 36
# else
# 20220304 20230227
# 36
# 37
# else
# 20220304 20230227
# 37
# 끝
# 끝끝 37
# <Response [200]>
# da: 2023.02.08.
# 1
# else
# 20220213 20230208
# 1
# 2
# else
# 20220213 20230208
# 2
# 3
# else
# 20220213 20230208
# 3
# 끝
# 끝asd 3
# 4
# else
# 20220213 20230208
# 4
# 끝
# 끝끝 4
# <Response [200]>
# da: 2022.08.23.
# 1
# else
# 20210828 20220823
# 1
# 2
# else
# 20210828 20220823
# 2
# 끝
# 끝asd 2
# 3
# else
# 20210828 20220823
# 3
# 끝
# 끝asd 3
# 4
# else
# 20210828 20220823
# 4
# 끝
# 끝끝 4
# <Response [200]>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [161], in <cell line: 171>()
#     167         joongoNara(i,date,digital,d_url)
#     170 digital_name('s23')
# --> 171 execution(101,'20230328','s23',s23)
#
# Input In [161], in execution(i, date, digital, d_url)
#     165 for i in range(1,i+1):
#     166     print(i)
# --> 167     joongoNara(i,date,digital,d_url)
#
# Input In [161], in joongoNara(page, date, digital, d_url)
#     110         #date3= datetime.strftime(da,"%Y.%m.%d.")
#     111         date3 = date3.strftime("%Y%m%d")
# --> 113         return execution(101,date3,digital,d_url)
#     115         # 전 페이지의 날짜를 가져와서 그 날짜로 중고나라 검색 다시하기
#     116
#     117
#    (...)
#     125
#     126 # 안에 있는 데이터 뽑기 반복
#     128 for item in junggos:
#
# Input In [161], in execution(i, date, digital, d_url)
#     165 for i in range(1,i+1):
#     166     print(i)
# --> 167     joongoNara(i,date,digital,d_url)
#
# Input In [161], in joongoNara(page, date, digital, d_url)
#     110         #date3= datetime.strftime(da,"%Y.%m.%d.")
#     111         date3 = date3.strftime("%Y%m%d")
# --> 113         return execution(101,date3,digital,d_url)
#     115         # 전 페이지의 날짜를 가져와서 그 날짜로 중고나라 검색 다시하기
#     116
#     117
#    (...)
#     125
#     126 # 안에 있는 데이터 뽑기 반복
#     128 for item in junggos:
#
#     [... skipping similar frames: execution at line 167 (2 times), joongoNara at line 113 (1 times)]
#
# Input In [161], in joongoNara(page, date, digital, d_url)
#     110         #date3= datetime.strftime(da,"%Y.%m.%d.")
#     111         date3 = date3.strftime("%Y%m%d")
# --> 113         return execution(101,date3,digital,d_url)
#     115         # 전 페이지의 날짜를 가져와서 그 날짜로 중고나라 검색 다시하기
#     116
#     117
#    (...)
#     125
#     126 # 안에 있는 데이터 뽑기 반복
#     128 for item in junggos:
#
# Input In [161], in execution(i, date, digital, d_url)
#     165 for i in range(1,i+1):
#     166     print(i)
# --> 167     joongoNara(i,date,digital,d_url)
#
# Input In [161], in joongoNara(page, date, digital, d_url)
#      97 junggos = junggo.find("tbody").find_all("tr")
#      99 print(html)
# --> 100 da = junggos[0].find("td", class_="td_date").text
#     101 #print(junggo)
#     103 print("da:",da)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
len(number_s23)
# Out:
# 10568

# %%
# 첫번쨰 컨텐츠로 가야함. 그리고 main-area는 복수개이기 떄문에 find_all과 몇번쨰 area인지 확인을 해줘야함.
# 그래서 [0]을 써준 것임.
junggo = soup.find("div", id = "content-area").find_all("div",id="main-area")[0].find_all("div", class_="article-board")[1]
junggos = junggo.find("tbody").find_all("tr")

# %%
for item in junggos:
    title = item.find("td", class_="td_article")
    
    if title != None:
        source = title.find("div", class_="board-list").find("a", class_="article")
        
        if source.find(text=re.compile("14")): # 14만 출력이 된다.
            title = source.text
            url = source['href']
            print(" ".join(source.stripped_strings)) # 공백을 날리는 것이다.
            print("https://cafe.naver.com" + url)
            print('-'*100) # 그냥 선을 긋는 것.

# %%
# 데이트 구하는 법
date = '2022-01-01'
date=datetime.strptime(date,'%Y-%m-%d')
print(date)
print(type(date))

# %%
# date 구하기
from datetime import datetime

date_str = "2022.01.23."
date_obj = datetime.strptime(date_str, "%Y.%m.%d.")
formatted_date = date_obj.strftime("%Y%m%d")

print(formatted_date)

# %%
## 데이터가 없는 경우


html = requests.get(url= "https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.media=0%26search.searchdate=all%26search.exact=%26search.include=%26userDisplay=50%26search.exclude=%26search.option=0%26search.sortBy=date%26search.searchBy=1%26search.searchBlockYn=0%26search.includeAll=%26search.query=gram%26search.viewtype=title%26search.page=1")
soup = BeautifulSoup(html.text, "html.parser")
#junggo = soup.find("div", id = "content-area").find_all("div",id="main-area")[0].find_all("div", class_="article-board")[1]
date = junggo.find("tbody").find_all("tr").find

print(date)

## 데이터가 없는 경우

# %%
# 날짜 가져오기
# 3달전의 날짜 가져오기
# 2022.01.23을 20220123 으로 바꾸기 그걸 date1에 저장
# 날짜 text ,, 형식: 2022.01.23. 을 20220123 형식으로 str 형식으로 바꾸기


html = requests.get(url= "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.exact=&search.include=&userDisplay=50&search.exclude=&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.includeAll=&search.query=gram&search.viewtype=title&search.page=20")
    # query=%B1%D7%B7%A5 그램으로 검색했는데 이 부분이 암호화처리되어있는 것을 확인할 수 있었음.
    
soup = BeautifulSoup(html.text, "html.parser")
    
    ##만약 페이지안에 값이 없는 경우
    # 날짜 조정하기    
    
    # 첫번쨰 컨텐츠로 가야함. 그리고 main-area는 복수개이기 떄문에 find_all과 몇번쨰 area인지 확인을 해줘야함.

    # 그래서 [0]을 써준 것임.

    
# 날짜 text ,, 형식: 2022.01.23.
junggo = soup.find("div", id = "content-area").find_all("div",id="main-area")[0].find_all("div", class_="article-board")[1]
junggos = junggo.find("tbody").find_all("tr")
da = junggos[0].find("td", class_="td_date").text


# 2022.01.23을 20220123 으로 바꾸기 그걸 date1에 저장
date= datetime.strptime(da, "%Y.%m.%d.")
date1 = date.strftime("%Y%m%d")

print(date1)

date1 = datetime.strptime(date1,"%Y%m%d")
date2 = date- timedelta(days = 3*30)

print(date1)


date1 = date1.strftime("%Y%m%d")
date2 = date2.strftime("%Y%m%d")

print(date1)
print(date2)

# from datetime import datetime, timedelta

# date_str = "2022-01-23"
# date_obj = datetime.strptime(date_str, "%Y-%m-%d")

# three_months_ago = date_obj - timedelta(days=3*30)

# formatted_date = three_months_ago.strftime("%Y-%m-%d")
# print(formatted_date)

# 3달 전의 날짜 구하기
# Out:
# 20220122
# 2022-01-22 00:00:00
# 20220122
# 20211024

# %%
# 리스트 맘들기

def digital_name(digital):
    title_name = 'title_' + digital
    url_name = 'url_' + digital
    number_name = 'number_'+digital
    name_name = 'name_' + digital
    dates_name = 'dates_' + digital
    
    
    globals()[title_name] = []
    globals()[url_name] = []
    globals()[number_name] = []
    globals()[name_name] = []
    globals()[dates_name] = []

    
# 입력값 s23
# name_S23 이라는 리스트를 지정할 수 있도록 해줘야함.

name_s23 = []  # 'name_s23' 변수에 빈 리스트 할당
result = get_variable_by_input('s23')  # 's23'에 해당하는 변수를 반환하는 함수 호출
print(result)  # 'name_s23' 변수 출력

# %%
def get_variable_by_input(input_value):
    var_name = 'name_' + input_value  # 입력값으로부터 변수 이름 생성
    return locals()[var_name]  # 생성된 변수 이름의 값 반환

# %% [markdown]
# # 가격 뽑아오기

# %%
# 가격 뽑아오기
path = "C:\study\python\datadown\chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get("https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=2&userDisplay=50&inCafeSearch=true&searchBy=1&query=s22&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980890755&referrerAllArticles=true") 
driver.switch_to.frame("cafe_main")
time.sleep(1)
ele = driver.find_element(By.XPATH,'//*[@id="app"]/div/div/div[2]/div[2]/div[1]/div[1]/div[2]/div[2]/div[1]/div[1]/div[2]/strong')
print(ele.text)
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_13484\2025550764.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# 9,498,000원

# %%
price_s23
# Out:
# ['9,999,999원',
#  '2,990,000원',
#  '2,150,000원',
#  '2,989,999원',
#  '1,980,000원',
#  '1,980,000원',
#  '2,817,000원',
#  '9,999,999원',
#  '37,777,777원',
#  '3,154,000원',
#  '9,093,998원',
#  '1,280,000원',
#  '940,000원',
#  '1,250,000원',
#  '850,000원',
#  '1,290,000원',
#  '9,999,999원',
#  '9,999,999원',
#  '37,777,777원',
#  '2,990,000원',
#  '37,777,777원',
#  '10,000,000원',
#  '9,999,999원',
#  '9,498,000원',
#  '2,817,000원',
#  '70,000원',
#  '1,230,000원',
#  '930,000원',
#  '23,000원',
#  '1,290,000원',
#  '2,000원',
#  '37,777,777원',
#  '1,980,000원',
#  '1,380,000원',
#  '37,777,777원',
#  '9,999,999원',
#  '9,093,998원',
#  '9,999,999원',
#  '9,999,999원',
#  '1,280,000원',
#  '1,130,000원',
#  '1,290,000원',
#  '1,190,000원',
#  '920,000원',
#  '1,190,000원',
#  '1,380,000원',
#  '17,500원',
#  '9,999,999원',
#  '2,990,000원',
#  '37,777,777원',
#  '3,154,000원',
#  '1,980,000원',
#  '9,498,000원',
#  '9,999,999원',
#  '37,777,777원',
#  '2,150,000원',
#  '1,280,000원',
#  '2,150,000원',
#  '1,280,000원']

# %% [markdown]
# # 반복문으로 가격 가져오기

# %%
price_s23=[]
path = "C:\study\python\datadown\chromedriver.exe"
driver = webdriver.Chrome(path)
for e in url_s23:
    print(e)
    driver.get(e)
    time.sleep(0.5)
    driver.switch_to.frame("cafe_main")
    ele = driver.find_element(By.XPATH,'//*[@id="app"]/div/div/div[2]/div[2]/div[1]/div[1]/div[2]/div[2]/div[1]/div[1]/div/strong')
    price_s23.append(ele.text)
    print(ele.text)
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_25012\2531870584.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=1&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980902138&referrerAllArticles=true
# 9,999,999원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=2&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980899206&referrerAllArticles=true
# 2,990,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=3&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980895797&referrerAllArticles=true
# 2,150,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=4&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980892075&referrerAllArticles=true
# 2,989,999원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=5&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980888577&referrerAllArticles=true
# 1,980,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=6&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980884613&referrerAllArticles=true
# 1,980,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=7&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980880644&referrerAllArticles=true
# 2,817,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=8&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980876717&referrerAllArticles=true
# 9,999,999원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=9&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980871968&referrerAllArticles=true
# 37,777,777원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=10&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980866194&referrerAllArticles=true
# 3,154,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=11&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980854879&referrerAllArticles=true
# 9,093,998원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=12&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980843944&referrerAllArticles=true
# 1,280,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=13&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980824287&referrerAllArticles=true
# 940,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=14&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980793784&referrerAllArticles=true
# 1,250,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=15&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980748945&referrerAllArticles=true
# 850,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=16&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980717103&referrerAllArticles=true
# 1,290,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=17&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980694779&referrerAllArticles=true
# 9,999,999원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=18&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980692114&referrerAllArticles=true
# 9,999,999원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=19&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980688330&referrerAllArticles=true
# 37,777,777원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=20&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980685316&referrerAllArticles=true
# 2,990,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=21&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980680904&referrerAllArticles=true
# 37,777,777원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=22&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980674644&referrerAllArticles=true
# 10,000,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=23&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980667520&referrerAllArticles=true
# 9,999,999원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=24&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980659729&referrerAllArticles=true
# 9,498,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=25&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980649277&referrerAllArticles=true
# 2,817,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=26&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980629462&referrerAllArticles=true
# 70,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=27&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980597060&referrerAllArticles=true
# 1,230,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=28&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980553264&referrerAllArticles=true
# 930,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=29&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980516508&referrerAllArticles=true
# 23,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=30&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980497484&referrerAllArticles=true
# 1,290,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=31&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980486541&referrerAllArticles=true
# 2,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=32&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980483646&referrerAllArticles=true
# 37,777,777원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=33&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980480586&referrerAllArticles=true
# 1,980,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=34&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980477297&referrerAllArticles=true
# 1,380,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=35&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980473639&referrerAllArticles=true
# 37,777,777원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=36&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980469009&referrerAllArticles=true
# 9,999,999원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=37&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980464822&referrerAllArticles=true
# 9,093,998원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=38&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980459437&referrerAllArticles=true
# 9,999,999원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=39&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980453536&referrerAllArticles=true
# 9,999,999원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=40&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980446779&referrerAllArticles=true
# 1,280,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=41&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980437915&referrerAllArticles=true
# 1,130,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=42&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980425835&referrerAllArticles=true
# 1,290,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=43&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980406334&referrerAllArticles=true
# 1,190,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=44&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980368557&referrerAllArticles=true
# 920,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=45&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980340969&referrerAllArticles=true
# 1,190,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=46&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980320079&referrerAllArticles=true
# 1,380,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=47&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980298386&referrerAllArticles=true
# 17,500원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=48&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980294014&referrerAllArticles=true
# 9,999,999원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=49&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980290816&referrerAllArticles=true
# 2,990,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=50&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980287250&referrerAllArticles=true
# 37,777,777원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=51&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980283862&referrerAllArticles=true
# 3,154,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=52&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980280640&referrerAllArticles=true
# 1,980,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=53&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980276666&referrerAllArticles=true
# 9,498,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=54&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980272422&referrerAllArticles=true
# 9,999,999원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=55&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980267802&referrerAllArticles=true
# 37,777,777원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=56&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980261687&referrerAllArticles=true
# 2,150,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=57&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980252181&referrerAllArticles=true
# 1,280,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=58&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980242395&referrerAllArticles=true
# 2,150,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=59&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980226495&referrerAllArticles=true
# 1,280,000원
# https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=10050146&page=60&inCafeSearch=true&searchBy=1&query=s23&includeAll=&exclude=&include=&exact=&searchdate=2022040220230328&media=0&sortBy=date&articleid=980199125&referrerAllArticles=true
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [17], in <cell line: 4>()
#       7 time.sleep(0.5)
#       8 driver.switch_to.frame("cafe_main")
# ----> 9 ele = driver.find_element(By.XPATH,'//*[@id="app"]/div/div/div[2]/div[2]/div[1]/div[1]/div[2]/div[2]/div[1]/div[1]/div/strong')
#      10 price_s23.append(ele.text)
#      11 print(ele.text)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:830, in WebDriver.find_element(self, by, value)
#     827     by = By.CSS_SELECTOR
#     828     value = f'[name="{value}"]'
# --> 830 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="app"]/div/div/div[2]/div[2]/div[1]/div[1]/div[2]/div[2]/div[1]/div[1]/div/strong"}
#   (Session info: chrome=111.0.5563.147)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0068DCE3]
# 	(No symbol) [0x006239D1]
# 	(No symbol) [0x00534DA8]
# 	(No symbol) [0x0056019F]
# 	(No symbol) [0x005603AB]
# 	(No symbol) [0x0058EE62]
# 	(No symbol) [0x0057AF14]
# 	(No symbol) [0x0058D57C]
# 	(No symbol) [0x0057ACC6]
# 	(No symbol) [0x00556F68]
# 	(No symbol) [0x005580CD]
# 	GetHandleVerifier [0x00903832+2506274]
# 	GetHandleVerifier [0x00939794+2727300]
# 	GetHandleVerifier [0x0093E36C+2746716]
# 	GetHandleVerifier [0x00736690+617600]
# 	(No symbol) [0x0062C712]
# 	(No symbol) [0x00631FF8]
# 	(No symbol) [0x006320DB]
# 	(No symbol) [0x0063C63B]
# 	BaseThreadInitThunk [0x75407D69+25]
# 	RtlInitializeExceptionChain [0x770FB74B+107]
# 	RtlClearBits [0x770FB6CF+191]

# %% [markdown]
# # 타겟 만들기

# %%
# title_name = 'title_' + digital
# url_name = 'url_' + digital
# number_name = 'number_'+digital
# name_name = 'name_' + digital
# dates_name = 'dates_' + digital

#해야할 일 ,, s23플러스 기준으로.
# 타겟 가져오기
# 1. 텍스트에 아이폰, 울트라,s22,매입 있는 경우 해당 셀 삭제.

target=  [''*울트라*", "아이폰", ]
 if any(x in element["title"] for x in target) and not any(x in element["title"] for x in excepts):

# %%
p = re.compile('ab__')
a='absc'

a == p

# %%
# a = title_s23[0]
# b = pattern[1]
# for i in range(10):
#     a = title_s23[i]
#     matches = re.findall(a,b)
#     print(matches)
#     print(b)

# %%
# import re

# text = 'XABCD XA1234 XBXYZ'
# pattern = 'XA*'
pattern=['아이폰','울트라','매입']
# matches = re.findall(pattern, text)
for e in title_s23:
    for i in range(0, len(pattern)-1):
        matches = re.findall(e,pattern[i])
        # print(matches)

re.findall(pattern[0],title_s23[0])

# %%
import re

text = title_s23[0]
pattern = ['울트라','아이폰','삽니다']

matches = re.findall(pattern[0], text)
print(matches)
# Out:
# ['울트라', '울트라']

# %% [markdown]
#    ## 제목에 pattern이 없는 경우

# %%
matchess=[]
pattern = ['아이폰','s22','매입','구매','삽니다']
pattern_i = []
for i,e in enumerate(title_s23):
    for a in range(0, len(pattern)-1):
        
        matches = re.findall(pattern[a],e)
        
        # matches가 빈 리스트인 경우,, 패턴이 없는경우 ,, 삭제하지 말아야할 것
        if not matches:
            
            matchess.append(i)
            
        #패턴이 안에 있는 경우 ,, 그러니까 삭제해야할 것.
        else:
            pattern_i.append(i)
            matches=[]

# 리스트 안의 중복값 제거
pattern_i = list(set(pattern_i))

# 삭제해야할
print("삭제해야할 행의 수: {}".format(len(pattern_i)))
# Out:
# 삭제해야할 행의 수: 5762

# %%
len(title_s23)-len(pattern_i)
# Out:
# 223

# %%
title_s23 = title_s23[~title_s23.index.isin(pattern_i)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 title_s23 = title_s23[~title_s23.index.isin(pattern_i)]
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'isin'

# %% [markdown]
# # 데이터프레임 만들기

# %%
def digital_df(digital):
    title_name = 'title_' + digital
    url_name = 'url_' + digital
    number_name = 'number_'+digital
    name_name = 'name_' + digital
    dates_name = 'dates_' + digital
    digital_df = 'digital_' + digital
    
    
    globals()[title_name]
    globals()[url_name]
    globals()[number_name]
    globals()[name_name]
    globals()[dates_name]
    globals()[digital_df] = pd.DataFrame({ 'number':globals()[number_name],'date' : globals()[dates_name],'name':globals()[name_name], 'title':globals()[title_name] , 'url' : globals()[url_name]})
    
    
    return digital_df
    
digital_df('s23')

digital_S23 = digital_s23

# %%
digital_S23 = digital_S23[~digital_S23.index.isin(pattern_i)]
print(len(digital_S23))
# Out:
# 4806
# 10568

# %%
# 중복행 삭제
digital_S23.drop_duplicates()
# Out:
#             number        date           name  \
# 0      [980902138]  2023.03.28         신속하게거래
# 1      [980902027]  2023.03.28    최고가전국방문매입24
# 2      [980901990]  2023.03.28  폰85yo 24시매입점i
# 3      [980901745]  2023.03.28     중고나라공식매입업체
# 4      [980901476]  2023.03.28      전국최고가격삽니다
# ...            ...         ...            ...
# 10563  [914654536]  2022.05.03       cutebkbk
# 10564  [896851084]  2022.02.07       cutebkbk
# 10565  [892904125]  2022.01.18           세일장터
# 10566  [892709270]  2022.01.17           세일장터
# 10567  [867387257]  2021.09.20             상자
#
#                                                    title  \
# 0      아이폰14프로맥스 갤럭시Z폴드4갤럭시Z플립4 S23 울트라 플러스 S22 14 pr...
# 1      어디든방문매입 아이폰 갤럭시 s23 s22 s21 s20 울트라 플러스 노트20 z...
# 2      매입) 아이폰14 14프로 14프로맥스 S23 전기종 S22 전기종 Z폴드4 Z플립...
# 3      아이폰14 프로맥스 256/13 프로맥스/갤럭시 s23 울트라 256/z폴드4/z플...
# 4      아이폰 14프로 14프로맥스 14플러스 갤럭시 s23 울트라 s23 플러스 z폴드4...
# ...                                                  ...
# 10563                                태하 스텍스 s23 런닝머신 판매.
# 10564  헬스장 오픈 풀셋트 수입머신 싸이벡스 이글,vr3,라이프휘트니스,너틸러스(웨이트머신...
# 10565  [앱상품][판매완료][32 (30~35) 르꼬끄 스키복 보드복 s23 ][50,000원]
# 10566        [앱상품][32 (30~35) 르꼬끄 스키복 보드복 s23 ][50,000원]
# 10567                                 갤럭시 s23 bmw에디션 팝니다
#
#                                                      url
# 0      https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 1      https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 2      https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 3      https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 4      https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# ...                                                  ...
# 10563  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 10564  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 10565  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 10566  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 10567  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
#
# [10568 rows x 5 columns]

# %%
digital_S23['title'].head(20)

#1. 겹치는 number 제거.
#2. 어떤 사람이 너무 많이 파는지 업자 체크
#3.
# Out:
# 38                    갤럭시 s23 울트라512gb크림 단순개봉미사용폰판매합니다
# 47                               Bmw s23 울트라 에디션 판매합니다
# 55                             BMW 갤럭시 S23 M에디션 구성품 판매
# 67     스마트 싱스 or 버즈 프로2+랜덤 케이스99,000원 쿠폰( s23 사전예약 쿠폰)
# 77         [앱상품][판매완료]자급제)갤럭시 S23 울트라512G 크림과 버즈2프로 팝니
# 81                               S23 512g(크림) 스타벅스 에디션
# 82                    갤럭시 s23 울트라256gb팬텀블랙 자급제미개봉판매합니다
# 88                    갤럭시 s23 울트라512gb크림색상 자급제미개봉판매합니다
# 97                         S23 실리콘 그립 케이스(화이트) 미개봉 팝니다
# 99                      s23 울트라사고나서 받은 스마스트싱스 스테이션 팝니다
# 101                   갤럭시 s23 울트라256gb라벤더 자급제미사용폰판매합니다
# 107                     갤럭시 s23 울트라256gb크림 자급제미개봉판매합니다
# 110            [앱상품][판매완료](미개봉) 갤럭시 S23 울트라 512GB 크림색상
# 112                             케이스티파이 s23 플러스 케이스 새상품
# 116                      미개봉 S23 플러스 스마트뷰월렛 케이스(그린) 판매
# 131                                  갤럭시 S23 스타벅스 에디션❤
# 146                              S23 플러스 256기가 라벤더 미개봉
# 148                                    [앱상품] s23 정품케이스
# 152                                  S23 + 256기가 그라파이트
# 155                    갤럭시 s23 울트라 그린 자급제 120에팝니다 업자아님
# Name: title, dtype: object

# %%
# #html = requests.get(url= "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.exact=&search.include=&userDisplay=50&search.exclude=&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.includeAll=&search.query=gram&search.viewtype=title&search.page=" + str(page))
# a_url="https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.media=0%26search.searchdate=2022040220230328%26userDisplay=50%26search.option=0%26search.sortBy=date%26search.searchBy=1%26search.searchBlockYn=0%26search.query=s23%26search.viewtype=title%26search.page=1"
# html = requests.get(url = a_url)



# soup = BeautifulSoup(html.text, "html.parser")


html = requests.get(url= "https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.media=0&search.searchdate=all&search.exact=&search.include=&userDisplay=50&search.exclude=&search.option=0&search.sortBy=date&search.searchBy=1&search.searchBlockYn=0&search.includeAll=&search.query=gram&search.viewtype=title&search.page=20")
    # query=%B1%D7%B7%A5 그램으로 검색했는데 이 부분이 암호화처리되어있는 것을 확인할 수 있었음.
    
soup = BeautifulSoup(html.text, "html.parser")
    
    ##만약 페이지안에 값이 없는 경우
    # 날짜 조정하기    
    
    # 첫번쨰 컨텐츠로 가야함. 그리고 main-area는 복수개이기 떄문에 find_all과 몇번쨰 area인지 확인을 해줘야함.

    # 그래서 [0]을 써준 것임.

    
# 날짜 text ,, 형식: 2022.01.23.
junggo = soup.find("div", id = "content-area").find_all("div",id="main-area")[0].find_all("div", class_="article-board")[1]
junggos = junggo.find("tbody").find_all("tr")

# 첫번쨰 컨텐츠로 가야함. 그리고 main-area는 복수개이기 떄문에 find_all과 몇번쨰 area인지 확인을 해줘야함.
# 그래서 [0]을 써준 것임.
junggo = soup.find("div", id = "content-area").find_all("div",id="main-area")[0].find_all("div", class_="article-board")[1]
junggos = junggo.find("tbody").find_all("tr")





# 안에 있는 데이터 뽑기 반복

for item in junggos:

    title = item.find("td", class_="td_article")
    name_box = item.find("td", class_="td_name")
    date_box = item.find("td", class_="td_date")



    if title != None:
        source = title.find("div", class_="board-list").find("a", class_="article")
        inner_number = title.find("div", class_="board-number").find(class_="inner_number")
        name = name_box.find("div", class_="pers_nick_area").find("td", class_="p-nick").find("a", class_="m-tcol-c")
        dates = date_box.text

        if ':' in dates:
            dates = datetime.today().strftime("%Y.%m.%d")
        elif '.' in dates:
            dates = dates.strip('.')

        # 리스트에 넣기

        

        qwe.append(inner_number)

# %%
type(dates_s23[0])
for i in range(0,len(dates_s23)-1):
    dates_s23[i] = datetime.strptime(dates_s23[i],'%Y.%m.%d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [200], in <cell line: 2>()
#       1 type(dates_s23[0])
#       2 for i in range(0,len(dates_s23)-1):
# ----> 3     dates_s23[i] = datetime.strptime(dates_s23[i],'%Y.%m.%d')
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

# %%
1. 중고나라 돌리기

2. 중복된 행 제거하기
3. 앱상품은 따로 빼두기

4. 타겟으로 거르기
5. 일반,,가격표 뽑아오기
6. 앱상품,, 가격표 뽑아오기
# Out:
# 1

# %%
5000개 정도,,
1분에 30개씩 뽑아올 수 있어
1800개.
3시간.
